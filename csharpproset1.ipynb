// %% [markdown]
// # Q-1 C#

// %% [markdown]
// <b>What data type is each of the following? </b><br/>
// 5 <br/>
// 5.0 <br/>
// 5 > 1 <br/>
// '5' <br/>
// 5 * 2 <br/>
// '5' * 2 <br/>
// '5' + '2' <br/>
// 5 / 2 <br/>
// 5 % 2 <br/>
// {5, 2, 1} <br/>
// 5 == 3 <br/>
// Pi (the number)

// %% [markdown]
// | Question | Data type |
// | ----- | ----- |
// | 5 | Integer |
// | 5.0 | Float |
// | 5 > 1 | Boolean |
// | '5' | Char |
// | 5 * 2 | Integer |
// | '5' * 2 | Integer (Int32) |
// | '5' + '2' | Integer (Int32) |
// | 5 / 2 | Float |
// | 5 % 2 | Integer |
// | {5,2,1} | Array |
// | 5 == 3 | Assignment (boolean) |
// | Pi (the number) | User Defined |

// %% [markdown]
// # Question 2 C#

// %% [markdown]
// Write (and evaluate) C# expressions that answer these questions: <br/>
// a. How many letters are there in 'Supercalifragilisticexpialidocious'? <br/>
// b. Does 'Supercalifragilisticexpialidocious' contain 'ice' as a substring? <br/>
// c. Which of the following words is the longest:
// Supercalifragilisticexpialidocious, Honorificabilitudinitatibus, or
// Bababadalgharaghtakamminarronnkonn? <br/>
// d. Which composer comes first in the dictionary: 'Berlioz', 'Borodin', 'Brian',
// 'Bartok', 'Bellini', 'Buxtehude', 'Bernstein'. Which one comes last?

// %%
string s1 = "Supercalifragilisticexpialidocious";
// length of Supercalifragilisticexpialidocious
Console.WriteLine(s1.Length);
// contains ice as a substring
Console.WriteLine(s1.Contains("ice"));
// Out:
// 34
// True

// %%
string s1= "Supercalifragilisticexpialidocious";
string s2= "Honorificabilitudinitatibus";
string s3= "Bababadalgharaghtakamminarronnkonn";

Console.WriteLine("The length of string 1 is " +s1.Length);
Console.WriteLine("The length of string 2 is " +s2.Length);
Console.WriteLine("The length of string 3 is " +s3.Length);

if (s1.Length > s2.Length)
{
 if (s1.Length > s3.Length)
 {
  Console.WriteLine("The Longest One is " + s1);
 }
else
 {
  Console.WriteLine("The Longest One is " +s3);
 }
}

else
{
 if (s2.Length > s3.Length)
 {
   Console.WriteLine("The Longest One is " + s2);
 }
 else
 {
   Console.WriteLine("The Longest One is " + s3);
 }
}
// Out:
// The length of string 1 is 34
// The length of string 2 is 27
// The length of string 3 is 34
// The Longest One is Bababadalgharaghtakamminarronnkonn

// %%
System.Collections.Generic.SortedDictionary<int, string> nm = new System.Collections.Generic.SortedDictionary<int, string>();
            nm.Add(1, "Berlioz");
            nm.Add(2, "Borodin");
            nm.Add(3, "Brian");
            nm.Add(4, "Bartok");
            nm.Add(5, "Bellini");
            nm.Add(6, "Buxtehude");
            nm.Add(7, "Bernstein");

            foreach (KeyValuePair<int, string> kval in nm.OrderBy(key => key.Value))
            {
                Console.WriteLine(kval.Key + " " + kval.Value);
            }
// Out:
// 4 Bartok
// 5 Bellini
// 1 Berlioz
// 7 Bernstein
// 2 Borodin
// 3 Brian
// 6 Buxtehude

// %% [markdown]
// # Question 3 C#

// %% [markdown]
// Implement function triangleArea(a,b,c) that takes as input the lengths of the 3
// sides of a triangle and returns the area of the triangle. By Heron's formula, the area
// of a triangle with side lengths a, b, and c is
// s(s - a)(s -b)(s -c), where
// s = (a + b + c) /2.

// %%
class triangleArea
{
     public float area(float a, float b, float c)
 {
     double s = (a + b + c ) / 2;
     return (float)Math.Sqrt(s * (s - a) * (s - b) *(s - c));
 }
}

// %%
triangleArea t = new triangleArea();
Console.WriteLine (t.area(2,2,2));
// Out:
// 1.7320508

// %% [markdown]
// # Question 4 C#

// %% [markdown]
// Write a program in C# Sharp to separate odd and even integers in separate arrays.

// %%
public class Program
{
    public static void Main()
    {
        Console.WriteLine("Enter the no of elements which will stored in array:");
        int rdno = Convert.ToInt32(Console.ReadLine());
        int[] inp_array = new int[rdno];
        for(int a = 0 ; a < rdno; a++)
            {
                Console.WriteLine("element  "+ a +" : ");
                inp_array[a] = Convert.ToInt32(Console.ReadLine());
            }
        Console.WriteLine("The Even elements are:");
        for(int a = 0 ; a < rdno; a++){
            if(inp_array[a]%2 ==0)
            {
                Console.WriteLine(inp_array[a]);
            }
        }
        Console.WriteLine("The Odd elements are:");
        for(int a = 0 ; a < rdno; a++){
        if(inp_array[a]%2 != 0)
            {
                Console.WriteLine(inp_array[a]);
            }
        }
    }
}

// %% [markdown]
// ![Screenshot%20%283%29.png](attachment:Screenshot%20%283%29.png)

// %% [markdown]
// # Question 5 C#

// %% [markdown]
// a. Write a function inside(x,y,x1,y1,x2,y2) that returns True or False depending on whether the point (x,y) lies in the rectangle with lower left corner (x1,y1) and upper right corner (x2,y2).
//
// b. Use function inside() from part a. to write an expression that tests whether the point (1,1) lies in both of the following rectangles: one with lower left corner (0.3, 0.5) and upper right corner (1.1, 0.7) and the other with lower left corner (0.5, 0.2) and upper right corner (1.1, 2).

// %%
public bool inside(double x, double y, double x1, double y1, double x2, double y2)
{
        bool ck_output;
        if(x >= x1 & x <= x2 & y >=y1 & y <= y2)
        {
            ck_output = true;
        }
        else
        {
            ck_output = false;
        }
        return ck_output;
}

// %%
Console.WriteLine(inside(1,1,0,0,2,3));
// Out:
// True

// %%
Console.WriteLine(inside(-1,-1,0,0,2,3));
// Out:
// False
